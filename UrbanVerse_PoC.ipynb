# %% [markdown]
# # UrbanVerse PoC: Spatio-Temporal Forecasting & Urban Knowledge Integration
# This notebook demonstrates the Proof-of-Concept for **UrbanVerse**, fusing **PDFormer** (traffic dynamics) and **UrbanKGent** (semantic knowledge graph).

# %% [markdown]
# ## 1. Spatio-Temporal Traffic Forecasting (PDFormer)
# - **Dataset:** METR-LA (207 Highway Sensors)
# - **Horizon 1 (5-min):** MAE = 4.18 mph, RMSE = 7.24 mph, MAPE = 9.89%
# - **Horizon 12 (60-min):** MAE = 30.34 mph, RMSE = 32.69 mph

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 5))
ax1.imshow(mpimg.imread('pdformer_results.png'))
ax1.axis('off')
ax1.set_title('Forecasting Error Progression', fontsize=12, fontweight='bold')

ax2.imshow(mpimg.imread('ground_truth_vs_prediction.png'))
ax2.axis('off')
ax2.set_title('12-Hour Speed Profile: Ground Truth vs. Prediction', fontsize=12, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Structured Urban Knowledge Graph & Reasoning (UrbanKGent)
# Executes entity-relation topology and multi-hop spatial reasoning.

# %%
with open('urban_kg_scenario.py', 'r', encoding='utf-8') as f:
    exec(f.read())

# %% [markdown]
# ## 3. End-to-End Integrated Framework (UrbanVerse Integration)
# Fuses the spatio-temporal anomaly alert with multi-hop graph propagation.

# %%
with open('urbanverse_integration_pipeline.py', 'r', encoding='utf-8') as f:
    exec(f.read())
